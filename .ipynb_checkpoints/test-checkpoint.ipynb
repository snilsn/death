# %%
import pandas as pd
import tabula

# !java -version
# Out:
# java version "1.8.0_301"
# Java(TM) SE Runtime Environment (build 1.8.0_301-b09)
# Java HotSpot(TM) 64-Bit Server VM (build 25.301-b09, mixed mode)

# %%
df = tabula.read_pdf('death.pdf', stream = True, pages = 5)[0]
df.iloc[0,0] = 'Sterbedatum'
df
# Out:
# Got stderr: Sep 02, 2021 11:07:54 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNUNG: Using fallback font 'ArialMT' for 'MetaNormalLF-Roman'
# Sep 02, 2021 11:07:55 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNUNG: Using fallback font 'ArialMT' for 'MetaNormalLF-Roman'
#                         Jahr Sterbedatum Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                Sterbedatum      01.01.     02.01.     03.01.     04.01.
# 1  2021 ....................       3 547      3 529      3 412      3 710
# 2  2020 ....................       2 685      2 809      2 761      2 765
# 3  2019 ....................       2 639      2 642      2 610      2 782
# 4  2018 ....................       2 665      2 760      2 870      2 865
# 5  2017 ....................       2 912      3 085      2 923      2 973
# 6  2016 ....................       2 558      2 422      2 522      2 743
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
df.index = df['Jahr']
df.drop(columns = 'Jahr')
# Out:
#                           Sterbedatum Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# Jahr
# NaN                            01.01.     02.01.     03.01.     04.01.
# 2021 ....................       3 547      3 529      3 412      3 710
# 2020 ....................       2 685      2 809      2 761      2 765
# 2019 ....................       2 639      2 642      2 610      2 782
# 2018 ....................       2 665      2 760      2 870      2 865
# 2017 ....................       2 912      3 085      2 923      2 973
# 2016 ....................       2 558      2 422      2 522      2 743
#
#                           Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# Jahr
# NaN                           05.01.     06.01.     07.01.     08.01.
# 2021 ....................      3 554      3 631      3 570      3 559
# 2020 ....................      2 536      2 685      2 802      2 832
# 2019 ....................      2 818      2 616      2 749      2 823
# ...

# %%
df.T
# Out:
# Jahr            NaN  2021 ....................  2020 ....................  \
# Jahr            NaN  2021 ....................  2020 ....................
# Sterbedatum  01.01.                      3 547                      2 685
# Unnamed: 0   02.01.                      3 529                      2 809
# Unnamed: 1   03.01.                      3 412                      2 761
# Unnamed: 2   04.01.                      3 710                      2 765
# Unnamed: 3   05.01.                      3 554                      2 536
# Unnamed: 4   06.01.                      3 631                      2 685
# Unnamed: 5   07.01.                      3 570                      2 802
# Unnamed: 6   08.01.                      3 559                      2 832
# Unnamed: 7   09.01.                      3 448                      2 911
# Unnamed: 8   10.01.                      3 336                      2 886
# Unnamed: 9   11.01.                      3 551                      2 679
# ...
